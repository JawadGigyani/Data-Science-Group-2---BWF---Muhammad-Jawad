# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('HR_Attrition.csv')

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome    Education EducationField  EmployeeCount  \
# 0                 1     Bachelor  Life Sciences              1
# 1                 8  High School  Life Sciences              1
# 2                 2     Bachelor          Other              1
# 3                 3          PhD  Life Sciences              1
# 4                 2  High School        Medical              1
#
#    EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 0               1  ...                         1            80
# ...

# %% [markdown]
# # Scatter Plot

# %%
sns.set_style('dark')

sns.scatterplot(
    data=df, 
    x='MonthlyIncome', 
    y='TotalWorkingYears', 
    palette='hls',
    hue='Gender', 
    size='Gender'
)

plt.xlabel('Monthly Salary')
plt.ylabel('Total Working Hour')
plt.title('Monthly Salary by Working Hours')

plt.show()

# %% [markdown]
# # Line Plot

# %%
sns.set_style('whitegrid')

sns.lineplot(
    data=df, 
    x='NumCompaniesWorked', 
    y='PercentSalaryHike', 
    marker='o',
    palette='hls',
    hue='Education',
    ci=None
)

plt.xlabel('Years Worked at Compnay')
plt.ylabel('Salary Hike %')
plt.title('Salary Hike by Years Worked at Company')

plt.show()

# %% [markdown]
# # Bar Plot

# %%
sns.set_style('darkgrid')

plt.figure(figsize=(15, 7))
sns.barplot(
    data=df,
    x='HourlyRate',
    y='TotalWorkingYears',
    palette='Set2',
)

plt.xlabel('Hourly Rate')
plt.ylabel('Total Working Years')
plt.title('Hourly Rate by Total Working Years')

plt.show()

# %% [markdown]
# # Count Plot

# %%
sns.set_style('whitegrid')

sns.countplot(
    data=df,
    x='YearsSinceLastPromotion',
    palette='Paired'
    )

plt.xlabel('Years Since Last Promotion')
plt.ylabel('Count of Employees')
plt.title('Number of Employees by Years Since last Promotion')

plt.show()

# %% [markdown]
# # Box Plot

# %%
sns.set_style('darkgrid')

sns.boxplot(
    data=df,
    x='DistanceFromHome',
    y='Attrition',
    palette='tab10',
    hue='EducationField',
    )

plt.xlabel('Distance From Home')
plt.ylabel('Attrition')
plt.title('Attrtion by Distance From Home')

plt.show()
